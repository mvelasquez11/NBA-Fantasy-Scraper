# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import csv


import requests

scores = {}
for week in range(1, 17):
    r = requests.get('http://games.espn.com/ffl/api/v2/scoreboard', 
                     params={'leagueId': 123456, 'seasonId': 2017, 'matchupPeriodId': week})
    scores[week] = r.json()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8" class="next-head next-head"/>
#   <title class="next-head">
#    Fantasy Basketball League Rosters - ESPN
#   </title>
#   <meta content="Play ESPN Fantasy Basketball" name="description"/>
#   <meta content="116656161708917" property="fb:app_id"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="Play ESPN Fantasy Basketball" property="og:description"/>
#   <meta content="https://g.espncdn.com/s/fbalm/share.png" property="og:image"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="ESPN.com" property="og:site_name"/>
#   <meta content="Fantasy Basketball League Rosters - ESPN" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://fantasy.espn.com/basketball/league/rosters" property="og:url"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Play ESPN Fantasy Basketball" name="twitter:description"/>
#   <meta content="https://g.espncdn.com/s/fbalm/share.png" name="twitter:image"/>
#   <meta content="espn" name="twitter:site"/>
#   <meta content="Fantasy Basketball League Rosters - ESPN" name="twitter:title"/>
#   <meta content="https://fantasy.espn.com/basketball/league/rosters" name="twitter:url"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/static/espn-ui.css?00204" rel="stylesheet"/>
#   <link href="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/static/fixed-data-table.css" rel="stylesheet"/>
#   <link as="script" href="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/cf2c1db6-51b9-4f9d-be8a-ab776b2d59b2/page/basketball/league/rosters.js" rel="preload"/>
#   <link as="script" href="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/cf2c1db6-51b9-4f9d-be8a-ab776b2d59b2/page/_app.js" rel="preload"/>
#   <link as="script" href="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/cf2c1db6-51b9-4f9d-be8a-ab776b2d59b2/page/_error.js" rel="preload"/>
#   <link as="script" href="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/static/commons/main-050b33f39feae9ce6583.js" rel="preload"/>
#   <style id="__jsx-861046686">
#    body{color:#000;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI","Roboto","Oxygen","Ubuntu","Cantarell","Fira Sans","Droid Sans","Helvetica Neue",sans-serif;font-size:16px;height:100%;margin:0px;padding:0px;}
# main{display:block;}
# .bp-desktopLGPlus{min-width:1240px;}
# .Dropdown__Label{color:#1D1E1F;}
# .shell-container .dropdown__select{color:#151617;padding:0 30px 0 12px;}
# .margin-left-auto{margin-left:auto;}
# .players-table .Table2__th,.players-table .Table2__td{padding:0;}
# .Table2__th,.Table2__td{padding-left:12px;}
# .Table2__tbody,.tbody>.tr{border-bottom:1px solid #DCDDDF;}
# .Table2__colgroup+.Table2__colgroup .Table2__col:nth-child(1){border-left:1px solid #dcdddf;}
# .raised{position:relative;z-index:2;}
# .raised::before,.raised::after{content:'';height:100%;width:5px;position:absolute;top:0;}
# .raised::before{background:linear-gradient(270deg,rgba(0,0,0,.2),transparent);left:-5px;}
# .raised::after{background:linear-gradient(270deg,transparent,rgba(0,0,0,.2));right:-5px;}
# .icon-light{fill:#808080;}
# .layout__column{width:100px;}
# svg,svg use{pointer-events:none;}
# .FavMgmt__Col--Left{min-width:300px;}
# .FavMgmt__Col--Right{max-width:376px;}
# .unselectable{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# .Table2__th.border-right,.Table2__td.border-right{border-right:1px solid #DCDDDF;}
#   </style>
#   <style id="__jsx-763806470">
#    .Site__Header{box-shadow:none;}
#   </style>
#   <style id="__jsx-1647358489">
#    .bp-desktopPlus .NavMain__SubNav{z-index:1000008;}
# .NavSecondary{box-shadow:0 4px 2px -2px rgba(0,0,0,0.3);}
# .NavSecondary__Item{box-shadow:inset 0 0 0 #ff9000;vertical-align:top;}
# .NavSecondary__Item:not(.branding){overflow:hidden;}
# .NavSecondary__Item:hover{overflow:visible;}
# .NavSecondary__Item:focus-within{overflow:visible;}
# .NavSecondary__Item .NavSecondary__Link .icon-external{width:14px;}
# .NavMain__SubNav__Link:hover,.NavMain__SubNav__List .NavMain__SubNav .NavMain__Link:hover,.NavMain__SubNav__List .NavMain__SubNav__Link:hover{background:#ff9000;color:#fff;}
# .NavMain__SubNav__List .NavMain__SubNav__Link:focus-within{background:#ff9000;color:#fff;}
# .NavSecondary .NavMain__SubNav.NavMain__SubNav--secondary{display:block;}
# .bp-desktopPlus .NavMain__Secondary>.NavSecondary__Item:not(.NavSecondary__Item--brand):hover,.bp-desktopPlus .NavMain__Secondary>.right-subnav>.NavSecondary__Item:not(.NavSecondary__Item--brand):hover,.bp-desktopPlus .NavSecondary__Item.active:not(.NavSecondary__Item--brand){box-shadow:inset 0 -3px 0 #ff9000;}
# .bp-desktopPlus .NavMain__Secondary>.right-subnav>.NavSecondary__Item:not(.NavSecondary__Item--brand):focus-within,.bp-desktopPlus .NavMain__Secondary>.NavSecondary__Item:not(.NavSecondary__Item--brand):focus-within{box-shadow:inset 0 -3px 0 #ff9000;}
# .NavMain__SubNav.myTeams .NavMain__SubNav__Link,.NavMain__SubNav.teams .NavMain__SubNav__Link{display:block;overflow:hidden;height:auto;}
# .NavMain__SubNav.myTeams .NavSecondary__Logo,.NavMain__SubNav.teams .NavSecondary__Logo{height:30px;display:inline-block;width:38px;}
# .NavMain__SubNav.myTeams .NavSecondary__TextContainer,.NavMain__SubNav.teams .NavSecondary__TextContainer{display:inline-block;width:calc(100% - 38px);}
# .NavMain__SubNav .NavSecondary__Logo img{display:block;height:30px;width:30px;}
# .NavMain__SubNav .NavSecondary__Logo img.custom-logo{border-radius:50%;}
# .NavMain__SubNav.myTeams .NavMain__Text,.NavMain__SubNav.teams .NavMain__Text{color:#222;display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;width:auto;}
# .NavMain__SubNav.myTeams .NavMain__Text.sub,.NavMain__SubNav.teams .NavMain__Text.sub{color:#ccc;font-size:11px;width:auto;display:block;}
# .NavMain__SubNav.myTeams .NavMain__SubNav__Link:hover .NavMain__Text,.NavMain__SubNav.teams .NavMain__SubNav__Link:hover .NavMain__Text{color:#fff;}
# .NavMain__SubNav.myTeams .NavMain__SubNav__Link:focus-within .NavMain__Text,.NavMain__SubNav.teams .NavMain__SubNav__Link:focus-within .NavMain__Text{color:#fff;}
# .NavMain__SubNav.is--split .NavMain__SubNav__Item,.NavMain__SubNav.myTeams .NavMain__SubNav__Item,.NavMain__SubNav.teams .NavMain__SubNav__Item{max-width:400px;min-width:200px;list-style:none;display:block;clear:both;white-space:nowrap;}
# .NavMain__SubNav__Item.getAnotherTeam span.NavMain__Text:before{content:'+';padding-right:4px;}
# .NavMain__SubNav.is--split:not(.myTeams):not(.teams) .NavMain__SubNav__Item{min-width:150px;max-width:250px;}
# .NavSecondary .right-subnav{position:absolute;right:0;text-align:right;}
# .NavSecondary .right-subnav .tsn-logo.NavSecondary__Item{vertical-align:top;}
# .NavSecondary .right-subnav .NavMain__SubNav{right:0;left:auto;text-align:left;}
# .NavMain__SubNav.teams .NavMain__SubNav__Item .owners .owner-name + .owner-name::before{content:', ';}
# .NavSecondary ul.NavMain__SubNav__List--secondary{padding:0 8px;min-width:200px;width:auto;}
# .NavSecondary__Link > .icon__svg{height:auto;}
# .NavSecondary .NavSecondary__Split{-ms-flex-preferred-size:auto;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}
# .NavSecondary .NavSecondary__Item + .tsn-logo.NavSecondary__Item .NavSecondary__Link:before{position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);height:calc(100% - 20px);width:1px;left:-1px;content:"";background:#dcdddf;}
# .NavSecondary .tsn-logo.NavSecondary__Item .NavSecondary__Logo{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;}
# .NavSecondary .tsn-logo.NavSecondary__Item img{display:block;}
#   </style>
#   <style id="__jsx-979094127">
#    .shell-container.jsx-979094127 .page-container .leagueHistoryModeInShell,.shell-container.jsx-979094127 .page-container .league-deleted{background:#fff;font-size:12px;}
# .shell-container.jsx-979094127 .shell--header .layout__column--1 .container{height:250px;}
# .shell-container.gated.jsx-979094127{background:#fff;position:absolute;height:100%;width:100%;}
# @media only screen and (max-width:425px){.shell-container.gated.jsx-979094127 .signup-closed__container{border-radius:0 !important;}.shell-container.gated.jsx-979094127 .page-container{padding:0 !important;}}
# @media only screen and (min-width:1024px){.shell-container.game-wallpaper.jsx-979094127{background:transparent url(https://g.espncdn.com/lm-static/fba/images/background.png) no-repeat 50% 4px;background-size:1474px 1326px;padding:20px 0;}.shell-container.gated.jsx-979094127 .signup-closed__container{max-width:765px;margin:0 auto;border-radius:10px;}}
#   </style>
#   <style id="__jsx-2320949408">
#    .league-rosters-tables.jsx-2320949408 .matchupTable{background-color:#FFF;}
# .league-rosters-tables.jsx-2320949408 .roster-btn{width:175px;text-align:center;line-height:30px;margin:24px 10px 20px 10px;}
# .league-rosters-tables.jsx-2320949408 .rosterTable .teamName{text-overflow:ellipsis;overflow:hidden;white-space:nowrap;max-width:200px;}
# .league-rosters-shell .shell-container #games-footercol{margin-top:-10px;}
# .league-rosters-tables.jsx-2320949408 .table--cell{padding-right:8px;padding-left:8px;}
# .league-rosters-tables.jsx-2320949408 .InnerLayout__child{border-radius:10px;}
# .league-rosters-shell .shell-container .loader{margin-bottom:12px;}
#   </style>
#   <style id="__jsx-397728423">
#    .container.jsx-397728423{background:#fff;padding:12px 12px 12px 12px;border-radius:10px;}
# .container.gameBorder.jsx-397728423{padding-top:16px;position:relative;}
# .container.gameBorder.jsx-397728423::before{content:'';display:block;position:absolute;top:0;left:0;height:6px;width:100%;background-color:#ff9000;border-radius:10px 10px 0 0;}
# .container.gameBorder.jsx-397728423 .headers.jsx-397728423{margin-top:0;}
# .headers.jsx-397728423{margin:10px 0 6px 0;display:inline-block;}
# .header.jsx-397728423,.subHeader.jsx-397728423{display:inline-block;line-height:32px;vertical-align:top;}
# .header.jsx-397728423{color:#151617;font-size:24px;}
# .header.jsx-397728423+.subHeader.jsx-397728423{margin-left:10px;margin-top:4px;}
# .subHeader.jsx-397728423{color:#4A4A4A;font-weight:normal;font-size:12px;}
#   </style>
#   <style id="__jsx-4158115014">
#    .loader.jsx-4158115014{background:#ffffff;position:relative;border-radius:10px;}
# div.overlap-loader.jsx-4158115014{background:rgba(255,255,255,0.80);position:absolute;z-index:9;left:0;top:0;}
#   </style>
#   <style id="__jsx-3788716136">
#    #games-footercol.jsx-3788716136 .sl-horizontal,.sl-vertical{background:url('data:image/svg+xml;base64,...') center center no-repeat;background-size:100px;}
# #games-footercol.jsx-3788716136 .sl-horizontal{min-height:100px;}
# #games-footercol.jsx-3788716136 .sl-vertical{min-height:250px;}
# #games-footercol.jsx-3788716136 .sl-wrapper{background:#fff;border-radius:10px;overflow:hidden;padding:0 10px;}
# #games-footercol.jsx-3788716136 .sl-wrapper .ob-widget-items-container,.ob-rec-source{padding-bottom:0 !important;}
# #games-footercol.jsx-3788716136 .sl-wrapper .trc_rbox_header{padding-top:10px !important;}
# #games-footercol.jsx-3788716136 .sl-header{display:none;font-size:14px;font-weight:600;top:12px;}
#   </style>
#   <style id="__jsx-191909990">
#    .SupportModule.jsx-191909990{background:#fff;border-radius:10px;padding:14px;margin:10px 0;}
# .SupportModule__Header.jsx-191909990{float:left;width:100%;border-bottom:1px #DCDDDF solid;padding:0 0 14px;}
# .SupportModule.jsx-191909990 h1.jsx-191909990{float:left;font-size:16px;line-height:20px;font-weight:600;}
# .SupportModule.jsx-191909990 h2.jsx-191909990{float:left;line-height:20px;font-size:14px;margin-left:14px;border-left:1px #c0c0c0 solid;color:#c0c0c0;font-weight:normal;padding-left:14px;}
# .SupportModule__Body.jsx-191909990{width:100%;clear:both;}
# .SupportModule__Links.jsx-191909990{float:left;width:66%;padding:10px 8px 0;}
# .SupportModule__Button.jsx-191909990{float:left;width:34%;text-align:center;border-left:1px #DCDDDF solid;margin:14px auto 0;padding:10px 0;height:100%;}
# .SupportModule__ButtonLink.jsx-191909990{line-height:16px;font-size:14px;font-weight:bold;text-align:center;width:100%;padding-bottom:4px;display:block;}
# .SupportModule__ButtonLabel.jsx-191909990{line-height:12px;font-size:10px;text-align:center;width:100%;color:#9B9B9B;display:block;}
#   </style>
#   <style id="__jsx-1200692847">
#    ul.jsx-1200692847{float:left;list-style-type:none;padding:0;width:33%;}
# ul.jsx-1200692847 li.jsx-1200692847{padding:0;font-weight:normal;font-size:14px;line-height:28px;list-style-type:none;}
#   </style>
#   <style id="__jsx-3963490571">
#    p.jsx-3963490571{margin:1em 0;}
# footer.jsx-3963490571{color:#666;font-size:10px;padding-left:25px;text-align:center;}
#   </style>
#   <style id="__jsx-4255348631">
#    .changes-confirmation-modal.jsx-4255348631 .changes-confirmation-modal__LightBox{height:195px;width:375px;}
# .changes-confirmation-modal.jsx-4255348631 .lightbox__content .confirmation_popup_buttons{width:296px;margin-left:40px;}
# .changes-confirmation-modal.jsx-4255348631 .popup-description{height:60px;width:303px;margin:38px 35px 18px 37px;}
#   </style>
#   <style id="__jsx-2190202486">
#    .bp-tabletPlus .lightbox__content{max-height:none;}
# .lightbox__header{min-height:initial;}
# .lightbox__wrapper{bottom:0;left:0;position:fixed;right:0;top:0;-webkit-animation:.2s lightboxActivate-jsx-2190202486 .2s forwards;animation:.2s lightboxActivate-jsx-2190202486 .2s forwards;-webkit-animation-timing-function:cubic-bezier(.23,1,.32,1);animation-timing-function:cubic-bezier(.23,1,.32,1);}
# .lightbox__overlay{-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;-webkit-animation:.2s lightboxOverlayActive-jsx-2190202486 ease-in-out;animation:.2s lightboxOverlayActive-jsx-2190202486 ease-in-out;bottom:0;cursor:pointer;left:0;pointer-events:auto;position:absolute;right:0;top:0;}
# .lightbox__contentBox{max-width:768px;}
#   </style>
#  </head>
#  <body>
#   <div id="__next-wrapper">
#    <div id="__next">
#     <div id="espn-analytics">
#      <div class="bp-mobileMDPlus bp-mobileLGPlus league-rosters-shell bp-tabletPlus bp-desktopPlus bp-desktopLGPlus no-touch">
#       <div>
#       </div>
#       <div class="navigation__container sticky top-0 Site__Header">
#        <div class="jsx-763806470" style="height:44px">
#         <div class="Site__Header db left-0 top-0 sticky w-100 bg-clr-gray-02 Site__Header--espn">
#          <nav class="Nav__Primary center flex justify-between items-center">
#           <div class="Nav__Primary__Branding__Logo">
#            <h1>
#             <a class="Nav__Primary__ToggleMenu" href="#">
#              <span>
#               Menu
#              </span>
#             </a>
#             <a class="Nav__Primary__Branding Nav__Primary__Branding--espn" href="http://www.espn.com">
#              ESPN
#             </a>
#            </h1>
#           </div>
#           <ul class="Nav__Primary__Menu flex Nav__Primary__Menu--left w-100">
#            <li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative">
#             <a class="Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/nfl/" tabindex="0">
#              <span class="Nav__Text">
#               NFL
#              </span>
#             </a>
#             <span aria-hidden="true" style="display:none">
#              <div class="Nav__Dropdown absolute" style="display:block">
#               <div class="Nav__Dropdown__Wrapper flex pa3 bg-clr-white">
#                <div class="flex">
#                 <ul class="Nav__Dropdown__Menu__List">
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/">
#                    <span class="Nav__Text">
#                     Home
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/scoreboard">
#                    <span class="Nav__Text">
#                     Scores
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/schedule">
#                    <span class="Nav__Text">
#                     Schedule
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/standings">
#                    <span class="Nav__Text">
#                     Standings
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/stats">
#                    <span class="Nav__Text">
#                     Stats
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/teams">
#                    <span class="Nav__Text">
#                     Teams
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 justify-between clr-gray-01" href="http://www.vividseats.com/nfl?wsUser=717&amp;wsVar=NFLindexnav" rel="noopener" target="_blank">
#                    <span class="Nav__Text">
#                     Tickets
#                    </span>
#                    <svg class="Nav__Dropdown__Menu__ExternalIcon icon__svg" role="img" viewbox="0 0 24 24">
#                     <use xlink:href="#icon__external">
#                     </use>
#                    </svg>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="https://www.espn.com/nfl/story/_/id/28052040/week-11-nfl-power-rankings-1-32-poll-plus-biggest-game-left-team">
#                    <span class="Nav__Text">
#                     Power Rankings
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/story/_/id/27493008/nfl-depth-charts-all-32-teams">
#                    <span class="Nav__Text">
#                     Depth Charts
#                    </span>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="Nav__Dropdown__Menu__Link db flex items-center ns7 pa3 clr-gray-01" href="http://www.espn.com/nfl/injuries">
#                    <span class="Nav__Text">
#                     Injuries
#                    </span>
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#                <ul class="Nav__Dropdown__Group flex pa3 bg-clr-gray-09 flex-wrap is--4">
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   AFC East
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/buf/buffalo-bills">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Bills
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/mia/miami-dolphins">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Dolphins
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/ne/new-england-patriots">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Patriots
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/nyj/new-york-jets">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Jets
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   AFC North
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/bal/baltimore-ravens">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Ravens
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/cin/cincinnati-bengals">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Bengals
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/cle/cleveland-browns">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Browns
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/pit/pittsburgh-steelers">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Steelers
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   AFC South
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/hou/houston-texans">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Texans
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/ind/indianapolis-colts">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Colts
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/jax/jacksonville-jaguars">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Jaguars
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/ten/tennessee-titans">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Titans
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   AFC West
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/den/denver-broncos">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Broncos
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/kc/kansas-city-chiefs">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Chiefs
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/lac/los-angeles-chargers">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Chargers
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/oak/oakland-raiders">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Raiders
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   NFC East
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/dal/dallas-cowboys">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Cowboys
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/nyg/new-york-giants">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Giants
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/phi/philadelphia-eagles">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Eagles
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/wsh/washington-redskins">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Redskins
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   NFC North
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/chi/chicago-bears">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Bears
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/det/detroit-lions">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Lions
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/gb/green-bay-packers">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Packers
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/min/minnesota-vikings">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Vikings
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   NFC South
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/atl/atlanta-falcons">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Falcons
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/car/carolina-panthers">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Panthers
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/no/new-orleans-saints">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Saints
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/tb/tampa-bay-buccaneers">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Buccaneers
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </section>
#                 <section class="Nav__Dropdown__Group__Section pv3">
#                  <h2 class="Nav__Dropdown__Group__Section__Title mb3 ph3 h8 clr-gray-03">
#                   NFC West
#                  </h2>
#                  <div class="flex">
#                   <ul class="Nav__Dropdown__Group__Section__List">
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/ari/arizona-cardinals">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Cardinals
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/lar/los-angeles-rams">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        Rams
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/sf/san-francisco-49ers">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
#                       <div class="Image__Wrapper aspect-ratio--1x1">
#                        <img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/>
#                       </div>
#                      </figure>
#                      <span class="Nav__Text flex-expand clr-gray-04 n8 pl3">
#                       <span>
#                        49ers
#                       </span>
#                      </span>
#                     </a>
#                    </li>
#                    <li class="Nav__Dropdown__Group__Section__List__Item">
#                     <a class="Nav__Dropdown__Group__Link flex items-center ph3" href="http://www.espn.com/nfl/team/_/name/sea/seattle-seahawks">
#                      <figure class="Image aspect-ratio--parent Logo Nav__Dropdown__Group__Link__Logo flex-none Logo__sm">
# ...
#        </nav>
#       </div>
#       <div data-box-type="fitt-adbox-exclusions">
#        <div class="Ad ad-slot" data-category-exclusion="true" data-collapse-before-load="true" data-slot-kvps="pos=exclusions" data-slot-type="exclusions">
#        </div>
#       </div>
#       <div data-box-type="fitt-adbox-overlay">
#        <div class="Ad ad-slot" data-collapse-before-load="true" data-out-of-page="true" data-slot-kvps="pos=outofpage" data-slot-type="overlay">
#        </div>
#       </div>
#       <div class="jsx-979094127 shell-container">
#        <div data-box-type="fitt-adbox-banner">
#         <div class="Ad Ad--banner ad-slot" data-slot-kvps="pos=banner" data-slot-type="banner">
#         </div>
#        </div>
#        <div class="page-container cf">
#         <div class="layout is-full">
#          <div class="layout__column layout__column--1">
#           <div aria-label="League Rosters" class="jsx-397728423 container league-rosters-page mb4 pb7 FBA--container gameBorder" role="main">
#            <div class="jsx-397728423 headers">
#             <h1 class="jsx-397728423 header">
#              League Rosters
#             </h1>
#            </div>
#           </div>
#           <div class="jsx-2320949408 league-rosters-tables">
#            <div class="jsx-4158115014 loader" style="width:100%;height:300px">
#             <div class="LoadAnimation LoadAnimation--lightBG LoadAnimation--md">
#              <svg class="LoadAnimation__Spinner" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
#               <circle class="LoadAnimation__Path" cx="15" cy="15" fill="none" r="12" stroke-width="3">
#               </circle>
#              </svg>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="jsx-3788716136" id="games-footercol">
#          <div aria-label="Fantasy Basketball Support" class="jsx-191909990 SupportModule" role="contentinfo">
#           <div class="jsx-191909990 SupportModule__Body">
#            <div class="jsx-191909990 SupportModule__Header">
#             <h1 class="jsx-191909990">
#              Fantasy Basketball Support
#             </h1>
#            </div>
#            <div class="jsx-191909990 SupportModule__Links">
#             <ul class="jsx-1200692847">
#              <li class="jsx-1200692847">
#               <a class="jsx-1200692847" href="https://support.espn.com/hc/en-us/articles/360001117652-Username-and-Password-Help">
#                Username and Password Help
#               </a>
#              </li>
#              <li class="jsx-1200692847">
#               <a class="jsx-1200692847" href="https://support.espn.com/hc/en-us/articles/360001117532-Change-Email-Address">
#                Change Email Address
#               </a>
#              </li>
#             </ul>
#             <ul class="jsx-1200692847">
#              <li class="jsx-1200692847">
#               <a class="jsx-1200692847" href="https://support.espn.com/hc/en-us/articles/360000977312-Issues-Joining-a-League">
#                Issues Joining a League
#               </a>
#              </li>
#              <li class="jsx-1200692847">
#               <a class="jsx-1200692847" href="https://support.espn.com/hc/en-us/articles/360001141291-Login-and-Account-Issues">
#                Login and Account Issues
#               </a>
#              </li>
#             </ul>
#             <ul class="jsx-1200692847">
#              <li class="jsx-1200692847">
#               <a class="jsx-1200692847" href="https://support.espn.com/hc/en-us/articles/360000975632-Reset-Draft">
#                Reset Draft
#               </a>
#              </li>
#              <li class="jsx-1200692847">
#               <a class="jsx-1200692847" href="https://support.espn.com/hc/en-us/articles/360000973691-Find-Your-Team">
#                Find Your Team
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="jsx-191909990 SupportModule__Button">
#             <a class="jsx-191909990 SupportModule__ButtonLink" href="https://support.espn.com/hc/en-us/categories/360000057551-Fantasy-Basketball">
#              Fantasy Basketball Support
#             </a>
#             <div class="jsx-191909990 SupportModule__ButtonLabel">
#              Search the full library of topics.
#             </div>
#            </div>
#            <div class="jsx-191909990" style="clear:both">
#            </div>
#           </div>
#          </div>
#          <div>
#           <div class="sponsored-content sl-vertical">
#            <div class="sponsored-headlines relative sl-wrapper w-100 taboola">
#             <div id="leagueRosters-thumbnails-4x1-bottom">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <footer class="jsx-3963490571">
#          <p class="jsx-3963490571">
#           <strong class="jsx-3963490571">
#            <a class="jsx-3963490571" href="https://www.espn.com">
#             ESPN.com
#            </a>
#           </strong>
#           |
#           <a class="jsx-3963490571" href="https://r.espn.com/espn/memberServices">
#            Member Services
#           </a>
#           |
#           <a class="jsx-3963490571" href="https://www.espn.com/fantasy/">
#            Fantasy Games
#           </a>
#           |
#           <a class="jsx-3963490571" href="https://support.espn.com/hc/en-us/categories/360000057551-Fantasy-Basketball">
#            Help
#           </a>
#           |
#           <a class="jsx-3963490571" href="https://preferences.truste.com/2.0/?type=espn&amp;affiliateId=148" rel="noreferrer noopener" target="_blank">
#            Interest-Based Ads
#           </a>
#          </p>
#          <p class="jsx-3963490571">
#           Copyright ©
#           <!-- -->
#           2019
#           <!-- -->
#           ESPN Internet Ventures.
#           <a class="jsx-3963490571" href="https://disneytermsofuse.com/">
#            Terms of Use
#           </a>
#           and
#           <a class="jsx-3963490571" href="https://disney.go.com/corporate/privacy/pp_espn.html">
#            Privacy Policy and Safety Information/Your California Privacy Rights
#           </a>
#           are applicable to this site.
#           <br class="jsx-3963490571"/>
#           <br class="jsx-3963490571"/>
#           <span>
#            Officially Licensed Product of the National Basketball Players Association. Visit
#            <a href="https://www.nbpa.com" target="new">
#             www.nbpa.com
#            </a>
#            .
#           </span>
#          </p>
#         </footer>
#        </div>
#       </div>
#       <div class="jsx-4255348631 flex justify-between changes-confirmation-modal">
#       </div>
#       <div class="flex flex-column fixed bottom-0 w-100">
#        <div id="portal-stickybar">
#        </div>
#       </div>
#       <div id="modal-portal">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="__next-error">
#    </div>
#   </div>
#   <script>
#    typeof module==="object" && Object.defineProperty(module, "exports", { set: function(){} });
#   </script>
#   <script>
#    __KONA_SERIALIZATION_DATA__={"nav-data":{"teams":{"nfl":[{"name":"AFC East","teams":[{"id":"2","href":"http://www.espn.com/nfl/team/_/name/buf/buffalo-bills","name":"Buffalo Bills","shortName":"Bills","abbrev":"buf","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/buf.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"15","href":"http://www.espn.com/nfl/team/_/name/mia/miami-dolphins","name":"Miami Dolphins","shortName":"Dolphins","abbrev":"mia","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/mia.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"17","href":"http://www.espn.com/nfl/team/_/name/ne/new-england-patriots","name":"New England Patriots","shortName":"Patriots","abbrev":"ne","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/ne.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"20","href":"http://www.espn.com/nfl/team/_/name/nyj/new-york-jets","name":"New York Jets","shortName":"Jets","abbrev":"nyj","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/nyj.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"}]},{"name":"AFC North","teams":[{"id":"33","href":"http://www.espn.com/nfl/team/_/name/bal/baltimore-ravens","name":"Baltimore Ravens","shortName":"Ravens","abbrev":"bal","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/bal.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"4","href":"http://www.espn.com/nfl/team/_/name/cin/cincinnati-bengals","name":"Cincinnati Bengals","shortName":"Bengals","abbrev":"cin","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/cin.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"5","href":"http://www.espn.com/nfl/team/_/name/cle/cleveland-browns","name":"Cleveland Browns","shortName":"Browns","abbrev":"cle","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/cle.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"23","href":"http://www.espn.com/nfl/team/_/name/pit/pittsburgh-steelers","name":"Pittsburgh Steelers","shortName":"Steelers","abbrev":"pit","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/pit.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"}]},{"name":"AFC South","teams":[{"id":"34","href":"http://www.espn.com/nfl/team/_/name/hou/houston-texans","name":"Houston Texans","shortName":"Texans","abbrev":"hou","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/hou.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"11","href":"http://www.espn.com/nfl/team/_/name/ind/indianapolis-colts","name":"Indianapolis Colts","shortName":"Colts","abbrev":"ind","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/ind.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"30","href":"http://www.espn.com/nfl/team/_/name/jax/jacksonville-jaguars","name":"Jacksonville Jaguars","shortName":"Jaguars","abbrev":"jax","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/jax.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"10","href":"http://www.espn.com/nfl/team/_/name/ten/tennessee-titans","name":"Tennessee Titans","shortName":"Titans","abbrev":"ten","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/ten.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"}]},{"name":"AFC West","teams":[{"id":"7","href":"http://www.espn.com/nfl/team/_/name/den/denver-broncos","name":"Denver Broncos","shortName":"Broncos","abbrev":"den","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/den.png&w=80&h=80&cquality=40&scale=crop&location=origin&transparent=true"},{"id":"12","href":"http://www.espn.com/nfl/team/_/name/kc/kansas-city-chiefs","name":"Kansas City Chiefs","shortName":"Chiefs","abbrev":"kc","logo":"https://a.espn ...
#   </script>
#   <script>
#    __NEXT_DATA__ = {"props":{"pageProps":{"page":{"config":{"abbreviation":"FBA","acquisitionTypes":["FREEAGENCY","WAIVERS_TRADITIONAL","WAIVERS_CONTINUOUS"],"color":"#ff9000","colorRGB":"255, 144, 0","communicationFilterTypes":{"leagueChatFilter":"MSG_BOARD_GROUP","lmNoteFilter":"NOTE","matchupChatFilter":"MSG_BOARD_MATCHUP","messageBoardFilter":"MSG_BOARD","settingsFilter":"ACTIVITY_SETTINGS","transactionsFilter":"ACTIVITY_TRANSACTIONS","statusFilter":"ACTIVITY_STATUS","pollFilter":"POLL","scheduleFilter":"ACTIVITY_SCHEDULE"},"constants":{"communication":{"messageTypes":[{"active":false,"display":true,"displayOrder":0,"formatRequired":false,"id":0,"name":"CUSTOM"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_LIMIT_CHANGE","id":100,"name":"ACQUISITION_SETTINGS_LIMIT_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_MATCHUP_LIMITS_CHANGE","id":101,"name":"ACQUISITION_SETTINGS_MATCHUP_LIMITS_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_MIN_BID_CHANGE","id":102,"name":"ACQUISITION_SETTINGS_MIN_BID_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_TYPE_CHANGE","id":103,"name":"ACQUISITION_SETTINGS_TYPE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_WAIVER_HOURS_CHANGE","id":104,"name":"ACQUISITION_SETTINGS_WAIVER_HOURS_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISION_ADD","id":105,"name":"DIVISION_ADD"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISION_MODIFY","id":106,"name":"DIVISION_MODIFY"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISION_REMOVE","id":107,"name":"DIVISION_REMOVE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISIONS_UPDATE","id":108,"name":"DIVISIONS_UPDATE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_CURRENT_KEEPER_CHANGE","id":109,"name":"DRAFT_SETTINGS_CURRENT_KEEPER_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_CURRENT_KEEPER_DATE_CHANGE","id":110,"name":"DRAFT_SETTINGS_CURRENT_KEEPER_DATE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_DATE_CHANGE","id":111,"name":"DRAFT_SETTINGS_DATE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_FUTURE_KEEPER_CHANGE","id":112,"name":"DRAFT_SETTINGS_FUTURE_KEEPER_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_FUTURE_KEEPER_DATE_CHANGE","id":113,"name":"DRAFT_SETTINGS_FUTURE_KEEPER_DATE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_ORDER_CHANGE","id":114,"name":"DRAFT_SETTINGS_ORDER_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_ORDERTYPE_CHANGE","id":115,"name":"DRAFT_SETTINGS_ORDERTYPE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_TIME_PER_SELECTION_CHANGE","id":116,"name":"DRAFT_SETTINGS_TIME_PER_SELECTION_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_TRADING_CHANGE","id":117,"name":"DRAFT_SETTINGS_TRADING_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_TYPE_CHANGE","id":118,"name":"DRAFT_SETTINGS_TYPE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_STATUS_DRAFT_COMPLE ...
#           module={}
#           __NEXT_LOADED_PAGES__ = []
#           __NEXT_LOADED_CHUNKS__ = []
#
#           __NEXT_REGISTER_PAGE = function (route, fn) {
#             __NEXT_LOADED_PAGES__.push({ route: route, fn: fn })
#           }
#
#           __NEXT_REGISTER_CHUNK = function (chunkName, fn) {
#             __NEXT_LOADED_CHUNKS__.push({ chunkName: chunkName, fn: fn })
#           }
#
#           false
#   </script>
#   <script async="" id="__NEXT_PAGE__/basketball/league/rosters" src="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/cf2c1db6-51b9-4f9d-be8a-ab776b2d59b2/page/basketball/league/rosters.js">
#   </script>
#   <script async="" id="__NEXT_PAGE__/_app" src="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/cf2c1db6-51b9-4f9d-be8a-ab776b2d59b2/page/_app.js">
#   </script>
#   <script async="" id="__NEXT_PAGE__/_error" src="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/cf2c1db6-51b9-4f9d-be8a-ab776b2d59b2/page/_error.js">
#   </script>
#   <script async="" src="//cdn1.espn.net/kona/7e7aff1014f0-1.0.1689/_next/static/commons/main-050b33f39feae9ce6583.js">
#   </script>
#  </body>
# </html>
